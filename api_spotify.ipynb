# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisFernandoCampos/api_spotify/blob/main/api_spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Accedemos a la api de spotify**

# %%
# !pip install Spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_id="2dc59c0a28294a8ca2327ae345503f3d"
client_secret="b585de0c59a64be7996769859dc6900b"
# Configura tus credenciales
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# # **2. Obtemos la informacion de los 10 artistas top globales 2023**

# %%
# Ids de artistas globales (top 10)
artist_ids = ["06HL4z0CvFAxyc27GXpf02","4q3ewBCX7sLwd24euuV69X","1Xyo4u8uXC1ZmMpatF05PJ","3TVXtAsR1Inumwj472S9r4","12GqGscKJx3aE4t07u7eVZ",
              "2LRoIwlKmHjgvigdNGBHNo","0Y5tJX1MQlPlqiwlOH1tJY","7tYKF4w9nC0nq9CsPZTHyP","790FomKkXshlbRYZFtlgla","00FQb4jTyendYWaN8pK0wa"]

# Obtener información para cada artista
artist_info_list = []
for artist_id in artist_ids:
    artist_info = sp.artist(artist_id)
    artist_info_list.append(artist_info)

# %%
# Crear un DataFrame desde el diccionario obtenido
artist_df = pd.DataFrame(artist_info_list)

# Imprimir el DataFrame
artist_df.head(2)
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/0...
# 1  {'spotify': 'https://open.spotify.com/artist/4...
#
#                            followers                                   genres  \
# 0  {'href': None, 'total': 99275743}                                    [pop]
# 1  {'href': None, 'total': 78460836}  [reggaeton, trap latino, urbano latino]
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/06HL4z0CvFA...  06HL4z0CvFAxyc27GXpf02
# 1  https://api.spotify.com/v1/artists/4q3ewBCX7sL...  4q3ewBCX7sLwd24euuV69X
#
#                                               images          name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Taylor Swift
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Bad Bunny
#
#    popularity    type                                    uri
# 0         100  artist  spotify:artist:06HL4z0CvFAxyc27GXpf02
# ...

# %%
# Obtener los valores de la clave específica en las columnas
url = artist_df['external_urls'].apply(lambda x: x['spotify'])
followers = artist_df['followers'].apply(lambda x: x['total'])
id = artist_df["id"]
images = artist_df["images"].apply(lambda x: x[0]["url"])
name = artist_df['name']
popularity = artist_df['popularity']

# Crear un nuevo DataFrame con los valores obtenidos
artist_df = pd.DataFrame({
        'url': url,
        'followers': followers,
        "artist_id": id,
        "images": images,
        'name': name,
        'popularity': popularity
})

# Agregar la columna ranking
artist_df['ranking'] = range(1, 11)

# Imprimir el nuevo DataFrame
artist_df
# Out:
#                                                  url  followers  \
# 0  https://open.spotify.com/artist/06HL4z0CvFAxyc...   99275743
# 1  https://open.spotify.com/artist/4q3ewBCX7sLwd2...   78460836
# 2  https://open.spotify.com/artist/1Xyo4u8uXC1ZmM...   77772996
# 3  https://open.spotify.com/artist/3TVXtAsR1Inumw...   83949543
# 4  https://open.spotify.com/artist/12GqGscKJx3aE4...   10912066
# 5  https://open.spotify.com/artist/2LRoIwlKmHjgvi...    9321736
# 6  https://open.spotify.com/artist/0Y5tJX1MQlPlqi...   26439812
# 7  https://open.spotify.com/artist/7tYKF4w9nC0nq9...   17023495
# 8  https://open.spotify.com/artist/790FomKkXshlbR...   43391072
# 9  https://open.spotify.com/artist/00FQb4jTyendYW...   31587484
#
#                 artist_id                                             images  \
# 0  06HL4z0CvFAxyc27GXpf02  https://i.scdn.co/image/ab6761610000e5eb859e4c...
# 1  4q3ewBCX7sLwd24euuV69X  https://i.scdn.co/image/ab6761610000e5eb9ad50e...
# ...

# %%
# Escribimos nuestro dataframe
artist_df.to_excel("artist_df.xlsx", index=False)

# %% [markdown]
# # **3. Obtenemos info de las 10 canciones top de los 10 artistas top**

# %%
# Ids de artistas globales (top 10)
artist_ids = ["06HL4z0CvFAxyc27GXpf02","4q3ewBCX7sLwd24euuV69X","1Xyo4u8uXC1ZmMpatF05PJ","3TVXtAsR1Inumwj472S9r4","12GqGscKJx3aE4t07u7eVZ",
              "2LRoIwlKmHjgvigdNGBHNo","0Y5tJX1MQlPlqiwlOH1tJY","7tYKF4w9nC0nq9CsPZTHyP","790FomKkXshlbRYZFtlgla","00FQb4jTyendYWaN8pK0wa"]

# %%
# Lista de DataFrames
df_list = []

# Generar un DataFrame para cada artista
for artist_id in artist_ids:
    # Por defecto arroja las 10 mejores canciones
    top_tracks = sp.artist_top_tracks(artist_id)
    top_tracks_df = pd.DataFrame(top_tracks)
    top_tracks_df["artist_id"] = artist_id
    df_list.append(top_tracks_df)

# Concatenar todos los DataFrames de la lista verticalmente
artists_top_tracks_df = pd.concat(df_list, ignore_index=True)

# %%
artists_top_tracks_df.head(1)
# Out:
#                                               tracks               artist_id
# 0  {'album': {'album_type': 'album', 'artists': [...  06HL4z0CvFAxyc27GXpf02

# %%
# Explotamos la columna "tracks"
artists_top_tracks_df_n = pd.json_normalize(artists_top_tracks_df["tracks"])
artists_top_tracks_df_n.head(1)
# Out:
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit                                               href  \
# 0       178426     False  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
#
#                        id  is_local  is_playable          name  popularity  \
# 0  1BxfuPKGuaTgP7aM0Bbdwr     False         True  Cruel Summer          99
#
#    ...                                       album.images  album.is_playable  \
# 0  ...  [{'height': 640, 'url': 'https://i.scdn.co/ima...               True
#
#   album.name album.release_date album.release_date_precision  \
# 0      Lover         2019-08-23                          day
#
#   album.total_tracks album.type                             album.uri  \
# 0                 18      album  spotify:album:1NAmidJlEaVgA3MpcPFYGq
#
#   external_ids.isrc                              external_urls.spotify
# ...

# %%
# Fusionar el nuevo dataframe explotado y la columna "artist_id"
artists_top_tracks_df=pd.merge(artists_top_tracks_df["artist_id"],artists_top_tracks_df_n,left_index=True,right_index=True)
artists_top_tracks_df.head(3)
# Out:
#                 artist_id                                            artists  \
# 0  06HL4z0CvFAxyc27GXpf02  [{'external_urls': {'spotify': 'https://open.s...
# 1  06HL4z0CvFAxyc27GXpf02  [{'external_urls': {'spotify': 'https://open.s...
# 2  06HL4z0CvFAxyc27GXpf02  [{'external_urls': {'spotify': 'https://open.s...
#
#    disc_number  duration_ms  explicit  \
# 0            1       178426     False
# 1            1       229477     False
# 2            1       200690     False
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...  1BxfuPKGuaTgP7aM0Bbdwr
# 1  https://api.spotify.com/v1/tracks/1Iq8oo9Xkmmv...  1Iq8oo9XkmmvCQiGOfORiz
# 2  https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...  0V3wPSX9ygBnCm8psDIegu
#
#    is_local  is_playable                                               name  \
# 0     False         True                                       Cruel Summer
# ...

# %%
# Crear un nuevo DataFrame con los valores necesarios
artists_top_tracks_df = pd.DataFrame({
    "artist_id": artists_top_tracks_df["artist_id"],
    "duration_ms": artists_top_tracks_df["duration_ms"],
    "track_name": artists_top_tracks_df["name"],
    "popularity": artists_top_tracks_df["popularity"],
    "preview_url": artists_top_tracks_df["preview_url"],
    "album.images": artists_top_tracks_df["album.images"].apply(lambda x: x[0]["url"]),
    "album_name": artists_top_tracks_df["album.name"],
    "release_date": artists_top_tracks_df["album.release_date"]
})

# Imprimir el nuevo DataFrame
artists_top_tracks_df
# Out:
#                  artist_id  duration_ms  \
# 0   06HL4z0CvFAxyc27GXpf02       178426
# 1   06HL4z0CvFAxyc27GXpf02       229477
# 2   06HL4z0CvFAxyc27GXpf02       200690
# 3   06HL4z0CvFAxyc27GXpf02       221306
# 4   06HL4z0CvFAxyc27GXpf02       277831
# ..                     ...          ...
# 95  00FQb4jTyendYWaN8pK0wa       300683
# 96  00FQb4jTyendYWaN8pK0wa       351640
# 97  00FQb4jTyendYWaN8pK0wa       278126
# 98  00FQb4jTyendYWaN8pK0wa       281946
# 99  00FQb4jTyendYWaN8pK0wa       222920
#
#                                            track_name  popularity preview_url  \
# 0                                        Cruel Summer          99        None
# 1   Is It Over Now? (Taylor's Version) (From The V...          93        None
# 2                                           Anti-Hero          92        None
# 3                                               Lover          92        None
# 4                   You’re Losing Me (From The Vault)          92        None
# ...

# %%
# Escribimos nuestro dataframe
artists_top_tracks_df.to_excel("artist_top_tracks_df.xlsx", index=False)
